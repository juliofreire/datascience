# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading data
base = pd.read_csv("dados/trees.csv")
base.shape
# Out:
# (31, 3)

# %%
# A brief view
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
sns.distplot(base.Volume, bins=10, axlabel="Volume").set_title("Trees")
# Out:
# /home/julio/anaconda3/envs/MLpy37/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Trees')

# %%
# Loading another database
base2 = pd.read_csv("dados/chicken.csv")
base2.shape
# Out:
# (71, 2)

# %%
base2.head()
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean

# %%
# Groupby attribute feed
group = base2.groupby(["feed"])["weight"].sum()
group
# Out:
# feed
# casein       3883
# horsebean    1602
# linseed      2625
# meatmeal     3046
# soybean      3450
# sunflower    3947
# Name: weight, dtype: int64

# %%
# New dataframe to use filters of pandas
teste = base2.loc[base2["feed"] == "horsebean"]
teste
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean
# 5     168  horsebean
# 6     108  horsebean
# 7     124  horsebean
# 8     143  horsebean
# 9     140  horsebean

# %%
sns.distplot(base2.loc[base2["feed"] == "horsebean"].weight, hist=False).set_title("horsebean")
# Out:
# /home/julio/anaconda3/envs/MLpy37/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'horsebean')

# %%
sns.distplot(base2.loc[base2["feed"] == "casein"].weight, hist=True).set_title("casein")
# Out:
# /home/julio/anaconda3/envs/MLpy37/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'casein')

# %%
sns.distplot(base2.loc[base2["feed"] == "linseed"].weight, hist=True).set_title("linseed")
# Out:
# /home/julio/anaconda3/envs/MLpy37/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'linseed')

# %%
sns.distplot(base2.loc[base2["feed"] == "meatmeal"].weight, hist=True).set_title("meatmeal")
# Out:
# /home/julio/anaconda3/envs/MLpy37/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'meatmeal')

# %%
sns.distplot(base2.loc[base2["feed"] == "soybean"].weight, hist=True).set_title("soybean")
# Out:
# /home/julio/anaconda3/envs/MLpy37/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'soybean')

# %%
sns.distplot(base2.loc[base2["feed"] == "sunflower"].weight, hist=True).set_title("sunflower")
# Out:
# /home/julio/anaconda3/envs/MLpy37/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'sunflower')

# %%
fig, ax = plt.subplots(3,2)
plt.subplot(3,2,1)
sns.distplot(base2.loc[base2["feed"] == "casein"].weight, hist=True).set_title("casein")
plt.subplot(3,2,2)
sns.distplot(base2.loc[base2["feed"] == "horsebean"].weight, hist=True).set_title("horsebean")
plt.subplot(3,2,3)
sns.distplot(base2.loc[base2["feed"] == "linseed"].weight, hist=True).set_title("linseed")
plt.subplot(3,2,4)
sns.distplot(base2.loc[base2["feed"] == "meatmeal"].weight, hist=True).set_title("meatmeal")
plt.subplot(3,2,5)
sns.distplot(base2.loc[base2["feed"] == "soybean"].weight, hist=True).set_title("soybean")
plt.subplot(3,2,6)
sns.distplot(base2.loc[base2["feed"] == "sunflower"].weight, hist=True).set_title("sunflower")
plt.tight_layout()
# Out:
# /home/julio/anaconda3/envs/MLpy37/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/julio/anaconda3/envs/MLpy37/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
set(base2.feed)
# Out:
# {'casein', 'horsebean', 'linseed', 'meatmeal', 'soybean', 'sunflower'}
